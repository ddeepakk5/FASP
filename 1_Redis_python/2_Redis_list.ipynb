# %% [markdown]
# ## Redis List

# %%
import redis

# %%
hostname='redis-15300.c256.us-east-1-2.ec2.cloud.redislabs.com'
port = 15300
password = '7Ua4YbenqD4N7UQR18nX4A9XgRn7xvEN'
r = redis.Redis(
    host=hostname,
    port=port,
    password=password, 
    decode_responses=True)

# %%
r.ping()
# Out:
# True

# %%
r.lpush('mylist','value_1') # this will create a list with 1 value
# Out:
# 4

# %%
# to retrieve we use lindex or lrange
r.lindex(name='mylist',index=0)     
# return value on 0th index
# Out:
# 'value_1'

# %%
r.lpush('mylist','value_2')
# Out:
# 5

# %%
r.lrange('mylist',0,-1)
# Out:
# ['value_2', 'value_1', 'someval', 'value_2', 'value_1']

# %%
r.rpush('mylist','value_3')
# Out:
# 10

# %%
r.lrange('mylist',0,-1)
# Out:
# ['value_2',
#  'value_1',
#  'someval',
#  'value_2',
#  'value_1',
#  'value_2',
#  'value_1',
#  'value_3',
#  'value_3',
#  'value_3']

# %%
# lpushx and rpushx
r.lpushx('mylist1','somevalue')
# Out:
# 0

# %%
r.lrange('mylist1',0,-1)
# Out:
# []

# %%
r.lpushx('mylist','someval')
# Out:
# 11

# %%
r.lrange('mylist',0,-1)
# Out:
# ['someval',
#  'value_2',
#  'value_1',
#  'someval',
#  'value_2',
#  'value_1',
#  'value_2',
#  'value_1',
#  'value_3',
#  'value_3',
#  'value_3']

# %%
r.ltrim('mylist',start=0,end=2)
r.lrange('mylist',0,-1)
# Out:
# ['someval', 'value_2', 'value_1']

# %%
r.lmove()
