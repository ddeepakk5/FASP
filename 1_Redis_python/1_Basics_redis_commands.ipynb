# %%
import redis

# %%
hostname=''
port = 
password = ''
r = redis.Redis(
    host=hostname,
    port=port,
    password=password, 
    decode_responses=True)

# %%
## this is my redis string 
r.set(name='fool',value='bar')
# Out:
# True

# %%
r.get(name='fool')
# Out:
# 'bar'

# %%
r.keys()
# Out:
# ['mylist', 'fool', 'KEY', 'MESSAGE']
